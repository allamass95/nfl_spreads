# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string

file = ("Data Sources\Master Data Frame.csv")
NFL = pd.read_csv(file)
NFL.head()
# Out:
#    Rank                Winner                Loser  Points Winner  \
# 0     1   Philadelphia Eagles      Atlanta Falcons             18
# 1     2        Miami Dolphins     Tennessee Titans             27
# 2     3   Pittsburgh Steelers     Cleveland Browns             21
# 3     4  New England Patriots       Houston Texans             27
# 4     5     Minnesota Vikings  San Francisco 49ers             24
#
#    Points Loser              FAVORITE  SPREAD             UNDERDOG H/A  \
# 0            12       Atlanta Falcons    -1.0  Philadelphia Eagles   A
# 1            20      Tennessee Titans    -1.0       Miami Dolphins   A
# 2            21   Pittsburgh Steelers    -3.5     Cleveland Browns   A
# 3            20  New England Patriots    -6.0       Houston Texans   H
# 4            16     Minnesota Vikings    -6.0  San Francisco 49ers   H
#
#    Margin of Victory                      ...                       \
# 0                  6                      ...
# ...

# %%
NFL["Favorite Covers"] = if(NFL.loc[NFL[FAVORITE] == NFL[Spread Winner] = "Favorite Covers")
NFL.head()
# Out:
#   File "<ipython-input-9-e4f4f0628083>", line 1
#     NFL["Favorite Covers"] = if(NFL.loc[NFL[FAVORITE] == NFL[Spread Winner] = "Favorite Covers")
#                               ^
# SyntaxError: invalid syntax
